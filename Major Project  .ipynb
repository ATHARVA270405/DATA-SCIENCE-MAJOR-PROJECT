# %% [markdown]
# # Product Recommendation System For E-commerce

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use("ggplot")

import sklearn
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# ## Loading the dataset

# %%
amazon_ratings = pd.read_csv('ratings_Beauty.csv')
amazon_ratings = amazon_ratings.dropna()
amazon_ratings.head()
# Out:
#            UserId   ProductId  Rating   Timestamp
# 0  A39HTATAQ9V7YF  0205616461     5.0  1369699200
# 1  A3JM6GV9MNOF9X  0558925278     3.0  1355443200
# 2  A1Z513UWSAAO0F  0558925278     5.0  1404691200
# 3  A1WMRR494NWEWV  0733001998     4.0  1382572800
# 4  A3IAAVS479H7M7  0737104473     1.0  1274227200

# %%
amazon_ratings.shape
# Out:
# (2023070, 4)

# %%
popular_products = pd.DataFrame(amazon_ratings.groupby('ProductId')['Rating'].count())
most_popular = popular_products.sort_values('Rating', ascending=False)
most_popular.head(10)
# Out:
#             Rating
# ProductId
# B001MA0QY2    7533
# B0009V1YR8    2869
# B0043OYFKU    2477
# B0000YUXI0    2143
# B003V265QW    2088
# B000ZMBSPE    2041
# B003BQ6QXK    1918
# B004OHQR1Q    1885
# B00121UVU0    1838
# B000FS05VG    1589

# %%
most_popular.head(30).plot(kind = "bar")
# Out:
# <Axes: xlabel='ProductId'>

# %% [markdown]
# ### The above graph gives us the most popular product sold by the businesss in the descending order also it has conclude that product ID # B001MA0QY2 has sales of over 7000.

# %% [markdown]
# ## Now using the collaborative filtering method and using the Utility Matrix based on products sold and user reviews

# %%
# Subset of Amazon Ratings

amazon_ratings1 = amazon_ratings.head(10000)

# %%
ratings_utility_matrix = amazon_ratings1.pivot_table(values='Rating', index='UserId', columns='ProductId', fill_value=0)
ratings_utility_matrix.head()
# Out:
# ProductId              0205616461  0558925278  0733001998  0737104473  \
# UserId
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A03056581JJIOL5FSKJY7           0           0           0           0
# A03099101ZRK4K607JVHH           0           0           0           0
# A0505229A7NSH3FRXRR4            0           0           0           0
#
# ProductId              0762451459  1304139212  1304139220  130414089X  \
# UserId
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A03056581JJIOL5FSKJY7           0           0           0           0
# A03099101ZRK4K607JVHH           0           0           0           0
# A0505229A7NSH3FRXRR4            0           0           0           0
#
# ProductId              130414643X  1304146537  ...  B000052YPE  B000052YPF  \
# ...

# %% [markdown]
# #### As expected, the utility matrix obtaned above is sparce, I have filled up the unknown values wth 0.

# %%
ratings_utility_matrix.shape
# Out:
# (9697, 886)

# %% [markdown]
# ### Transposing the matrix

# %%
X = ratings_utility_matrix.T
X.head()
# Out:
# UserId      A00205921JHJK5X9LNP42  A024581134CV80ZBLIZTZ  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
#
# UserId      A03056581JJIOL5FSKJY7  A03099101ZRK4K607JVHH  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
#
# UserId      A0505229A7NSH3FRXRR4  A05492663T95KW63BR75K  \
# ProductId
# 0205616461                     0                      0
# 0558925278                     0                      0
# 0733001998                     0                      0
# ...

# %%
X.shape
# Out:
# (886, 9697)

# %% [markdown]
# ##### Unique products in subset of data

# %%
X1 = X

# %% [markdown]
# ### Decomposing the Matrix

# %%
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (886, 10)

# %% [markdown]
# ### Correlation Matrix

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (886, 886)

# %% [markdown]
# ####  Isolating Product ID # 6117036094 from the Correlation Matrix
# Assuming the customer buys Product ID # 6117036094 (randomly chosen)

# %%
X.index[99]
# Out:
# '6117036094'

# %% [markdown]
# ##### Index # of product ID purchased by customer

# %%
i = "6117036094"

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 99

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (886,)

# %% [markdown]
# ### Recommending top 10 highly correlated products in sequence

# %%
Recommend = list(X.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:9]
# Out:
# ['0733001998',
#  '1304482634',
#  '1457982633',
#  '3227001381',
#  '4057363823',
#  '5357955786',
#  '5357955905',
#  '5357956227',
#  '6053640972']

# %% [markdown]
# ### Product ID # Here are the top 10 products that will suggest to the customer on their past purchase history on website

# %% [markdown]
# ###### For a business without any user-item purchase history, a search engine based recommended system can be designed for users.The product recommendations can be based on textual clustering analysis given in product description.

# %%
# Importing libraries

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %% [markdown]
# ####  Item to item based recommendation system based on product description
# Applicable when business is setting up its E-commerce website for the first time

# %%
product_descriptions = pd.read_csv('product_descriptions.csv')
product_descriptions.shape
# Out:
# (124428, 2)

# %%
# Missing valuesproduct_descriptions = pd.read_csv('product_descriptions.csv')
product_descriptions.shape

product_descriptions = product_descriptions.dropna()
product_descriptions.shape
product_descriptions.head()
# Out:
#    product_uid                                product_description
# 0       100001  Not only do angles make joints stronger, they ...
# 1       100002  BEHR Premium Textured DECKOVER is an innovativ...
# 2       100003  Classic architecture meets contemporary design...
# 3       100004  The Grape Solar 265-Watt Polycrystalline PV So...
# 4       100005  Update your bathroom with the Delta Vero Singl...

# %%
product_descriptions1 = product_descriptions.head(500)
# product_descriptions1.iloc[:,1]

product_descriptions1["product_description"].head(10)
# Out:
# 0    Not only do angles make joints stronger, they ...
# 1    BEHR Premium Textured DECKOVER is an innovativ...
# 2    Classic architecture meets contemporary design...
# 3    The Grape Solar 265-Watt Polycrystalline PV So...
# 4    Update your bathroom with the Delta Vero Singl...
# 5    Achieving delicious results is almost effortle...
# 6    The Quantum Adjustable 2-Light LED Black Emerg...
# 7    The Teks #10 x 1-1/2 in. Zinc-Plated Steel Was...
# 8    Get the House of Fara 3/4 in. x 3 in. x 8 ft. ...
# 9    Valley View Industries Metal Stakes (4-Pack) a...
# Name: product_description, dtype: object

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X1 = vectorizer.fit_transform(product_descriptions1["product_description"])
X
# Out:
# UserId      A00205921JHJK5X9LNP42  A024581134CV80ZBLIZTZ  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
# ...                           ...                    ...
# B000052YPU                      0                      0
# B000052YPV                      0                      0
# B000052YPY                      0                      0
# B000052YQ0                      0                      0
# B000052YQ2                      0                      0
#
# UserId      A03056581JJIOL5FSKJY7  A03099101ZRK4K607JVHH  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# ...

# %% [markdown]
# ### Visualizing product clusters in subset of data

# %%
# Fitting K-Means to the dataset

X=X1

kmeans = KMeans(n_clusters = 10, init = 'k-means++')
y_kmeans = kmeans.fit_predict(X)
plt.plot(y_kmeans, ".")
plt.show()
# Out:
# C:\Users\Adesh.Chaudhari\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
def print_cluster(i):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print

# %% [markdown]
# ###  Output
# Recommendation of product based on the current product selected by user.
# To recommend related product based on, Frequently bought together.

# %% [markdown]
# ##### Top words in each cluster based on product description

# %%
# # Optimal clusters is 

true_k = 10

model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X1)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()
for i in range(true_k):
    print_cluster(i)
# Out:
# Top terms per cluster:
# Cluster 0:
#  concrete
#  vary
#  cement
#  product
#  epoxy
#  use
#  stake
#  designed
#  lb
#  store
# Cluster 1:
#  air
#  water
#  control
#  cooling
#  ft
#  cycle
#  oven
#  energy
#  wash
#  cooking
# Cluster 2:
#  door
#  wood
#  painted
#  proposition
#  nbsp
#  residents
#  california
#  65
#  primed
#  moulding
# Cluster 3:
#  ft
#  aluminum
#  easy
#  window
#  finish
#  patio
#  snow
#  10
#  cover
#  natural
# Cluster 4:
#  frame
#  light
#  collection
#  patio
#  dining
#  nickel
#  outdoor
#  watt
#  design
#  hardware
# Cluster 5:
#  power
#  volt
#  light
#  saw
#  battery
#  tool
#  watt
#  led
#  lithium
#  protection
# Cluster 6:
#  wall
#  storage
#  panels
#  shelves
#  lbs
#  room
#  home
#  unit
#  easy
#  steel
# Cluster 7:
#  cutting
#  easy
#  blade
#  tape
#  grass
#  pliers
#  joe
#  lightweight
#  easily
#  step
# Cluster 8:
#  toilet
#  bowl
#  flush
#  water
#  tank
#  piece
#  gal
#  wax
#  design
#  home
# Cluster 9:
# ...

# %% [markdown]
# ### Predicting clusters based on key search words

# %%
def show_recommendations(product):
    #print("Cluster ID:")
    Y = vectorizer.transform([product])
    prediction = model.predict(Y)
    #print(prediction)
    print_cluster(prediction[0])

# %% [markdown]
# ######  Keyword : cutting tool

# %%
show_recommendations("cutting tool")
# Out:
# Cluster 7:
#  cutting
#  easy
#  blade
#  tape
#  grass
#  pliers
#  joe
#  lightweight
#  easily
#  step

# %% [markdown]
# ##### Keyword : steel drill

# %%
show_recommendations("steel drill")
# Out:
# Cluster 1:
#  air
#  water
#  control
#  cooling
#  ft
#  cycle
#  oven
#  energy
#  wash
#  cooking

# %% [markdown]
# ##### In case a word appears in multiple clusters, the algorithm chooses the cluster with the highest frequency of occurance of the word.
#    keyword : Water

# %%
show_recommendations("water")
# Out:
# Cluster 1:
#  air
#  water
#  control
#  cooling
#  ft
#  cycle
#  oven
#  energy
#  wash
#  cooking

# %% [markdown]
# ####  Based on the product descriptions, the recommendation system can show products from the corresponding product clusters once a cluster has been identified based on the user's search terms.

# %% [markdown]
# #####  In summary, this is most effective for businesses that are just starting out with their e-commerce website and do not have any user-item purchase or rating history. After a buyer has a history of purchases, the recommendation engine can apply the model-based collaborative filtering technique, which will help the users receive a good recommendation right away.
